# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
from selenium import webdriver
import time

# %%
wd = webdriver.Chrome('/Users/jnhyn/Documents/Jun/4학년1학기/빅데이터/chromedriver')

# %%
#베스트 국내도서 중 여행 카테고리에서 크롤링
def Book_crawling(result,check):
    wd = webdriver.Chrome('/Users/jnhyn/Documents/Jun/4학년1학기/빅데이터/chromedriver')

    for i in ["1","2","3","4"]:
        url = "https://product.kyobobook.co.kr/bestseller/online?period=001#?page="+i+"&per=50&ymw=&period=001&saleCmdtClstCode=32&dsplDvsnCode=001&dsplTrgtDvsnCode=004&saleCmdtDsplDvsnCode="

        wd.get(url)
        time.sleep(15)

        if(check == 0):

            #카테고리의 화살표를 눌러 카테고리 전체 보기
            category_button1 = wd.find_element_by_xpath('//*[@id="domesticList"]/button')
            category_button1.click()
            time.sleep(15)

            #카테고리 중 "여행" 클릭
            category_button2 = wd.find_element_by_xpath('//*[@id="domesticList"]/div/ul/li[20]/button')
            category_button2.click()
            time.sleep(15)

            check = 1

        html = wd.page_source
        soupCB1 = BeautifulSoup(html, 'html.parser')

        try:
            #책 개수
            book_name_list = soupCB1.select("div.prod_info_box > a > span")
            book_len = len(book_name_list)

            for n in range(book_len):
                #책 이름
                book_name_list = soupCB1.select("div.prod_info_box > a > span")
                one_book_name = book_name_list[n].string

                #책 정보(지은이, 출판일)
                book_writer_list = soupCB1.select("div.prod_info_box > span.prod_author")
                one_book_writer_date = book_writer_list[n].get_text().strip()
                one_book_writer_date = one_book_writer_date.split('  · ')
                #책 지은이
                one_book_writer = one_book_writer_date[0]
                #책 출판일
                one_book_date = one_book_writer_date[1]


                #책 가격
                book_price_list = soupCB1.select("div.prod_info_box > div.prod_price > span.price > span.val")
                book_price = book_price_list[n].text


                result.append([one_book_name]+[one_book_writer]+[one_book_date]+[book_price])
        except:
            continue
            
    return

# %%
def main():
    result= []
    check = 0
    print('book crawling >>>>>>>>>>>>>>>>>>>>>>>>') 
    Book_crawling(result,check)
    print(result)
    CB_tbl = pd.DataFrame(result,columns =('name','writer','date','price')) 
    CB_tbl.to_csv('./2-최준현-201835753.csv', encoding = 'cp949', mode = 'w',index = True)

# %%
main()
# Out:
# book crawling >>>>>>>>>>>>>>>>>>>>>>>>
# [['전국김밥일주', '정다현(김밥큐레이터) ·  가디언 ', '2023.04.25', '16,200'], ['제 마음대로 살아보겠습니다', '이원지 ·  상상출판 ', '2019.11.13', '12,780'], ['미국 서부 셀프트래블(2022-2023)', '조은정 ·  상상출판 ', '2022.06.09', '16,200'], ['리얼 오사카(2023~2024)', '황성민 외 ·  한빛라이프 ', '2022.12.12', '16,920'], ['디스 이즈 오사카(This is Osaka)(2023)', '호밀씨 ·  테라출판사(TERRA) ', '2022.11.21', '17,820'], ['일본 현지 빵 대백과', '다쓰미출판 편집부 ·  클 ', '2023.04.17', '16,200'], ['리얼 도쿄(2023~2024)', '양미석 ·  한빛라이프 ', '2023.03.13', '18,900'], ['디스 이즈 도쿄(2023~2024)', '박설희 외 ·  테라출판사(TERRA) ', '2023.03.08', '17,820'], ['디스 이즈 홋카이도(This is Hokkaido)(2023)', '권예나 외 ·  테라출판사(TERRA) ', '2023.01.16', '16,920'], ['리얼 호주(2022~2023)', '박선영 외 ·  한빛라이프 ', '2022.05.30', '19,800'], ['그 해, 몽골', '신미영 ·  푸른향기 ', '2023.05.12', '15,120'], ['리얼 타이베이(2023~2024)', '김홍래 ·  한빛라이프 ', '2023.03.03', '17,820'], ['디스 이즈 이탈리아(2023~2024)', '전혜진 외 ·  테라출판사(TERRA) ', '2023.03.02', '18,900'], ['프렌즈 후쿠오카(2023~2024)', '정꽃나래 외 ·  중앙북스 ', '2023.02.06', '15,300'], ['저스트고 유럽 5개국(2023-2024)', '최철호 ·  시공사 ', '2023.03.24', '19,800'], ['디스 이즈 파리(2023-2024)', '김민준 외 ·  테라출판사(TERRA) ', '2023.03.20', '18,000'], ['무작정 따라하기 괌(2023-2024)', '김승남 외 ·  길벗 ', '2023.03.10', '17,820'], ['크로아티아 홀리데이(2023-2024)', '양인선 ·  꿈의지도 ', '2023.01.25', '16,200'], ['프렌즈 독일(2023~2024)', '유상현 ·  중앙북스 ', '2022.12.05', '21,600'], ['셀프트래블 북유럽(2022-2023)', '유진선 ·  상상출판 ', '2022.04.22', '17,010'], ['만약 우리의 언어가 위스키라고 한다면', '무라카미 하루키 ·  문학사상 ', '2020.06.18', '11,700'], ['산티아고 순례길을 걸으며 만나는 City & Town 가이드북(2023-2024)', '조대현 ·  해시태그 ', '2023.05.24', '17,010'], ['일본 소도시 여행', '박탄호 ·  넥서스BOOKS ', '2023.05.10', '19,800'], ['꿈꾸는 길, 산티아고', '김창현 ·  눈빛 ', '2023.05.01', '18,000'], ['제주 여행 참견', '장은정 ·  비타북스 ', '2023.05.01', '15,300'], ['토스카나 소도시 여행', '백상현 ·  시공사 ', '2023.04.27', '16,200'], ['특별하게 싱가포르(2023~2024)', '설혜원 ·  디스커버리미디어 ', '2023.04.20', '16,650'], ['무작정 따라하기 파리(2023-2024)', '오유나 ·  길벗 ', '2023.04.10', '21,600'], ['디스 이즈 스페인(This is Spain)(2023-2024)', '전혜진 ·  테라출판사(TERRA) ', '2023.04.03', '18,900'], ['해시태그 오스트리아 & 부다페스트(2023~2024)', '조대현 ·  해시태그 ', '2023.03.26', '16,200'], ['저스트고 런던(2023-2024)', '정기범 외 ·  시공사 ', '2023.03.24', '18,000'], ['저스트고 스페인(2023-2024)', '김지영 ·  시공사 ', '2023.03.24', '18,000'], ['무작정 따라하기 하와이(2023-2024)', '박재서 ·  길벗 ', '2023.03.23', '23,400'], ['무작정 따라하기 도쿄(2023-2024)', '정숙영 ·  길벗 ', '2023.03.10', '23,400'], ["베스트 프렌즈 도쿄('23~'24)", '정꽃나래 외 ·  중앙북스 ', '2023.03.06', '11,700'], ['차를 타고 떠나는 차 여행', '이유진 ·  페이퍼버드 ', '2023.02.28', '14,400'], ['나를 채우는 여행의 기술', '알랭 드 보통 ·  오렌지디 ', '2023.02.27', '13,500'], ['지금 바로, 도쿄(2023)', '이주호 외 ·  혜지원 ', '2023.01.12', '15,300'], ['뉴욕 셀프트래블(2023-2024)', '조은정 ·  상상출판 ', '2022.12.23', '14,850'], ['여행 말고 한달살기', '김은덕 외 ·  어떤책 ', '2022.10.20', '19,800'], ['프렌즈 하와이(2022~2023)', '이미정 ·  중앙북스 ', '2022.10.05', '20,700'], ['서울의 맛집(2023)', '블루리본 서베이 ·  BR미디어 ', '2022.09.27', '17,820'], ['특별하게 런던(2022~2023)', '김선태 ·  디스커버리미디어 ', '2022.09.20', '16,650'], ['독일 셀프트래블(2022-2023)', '김주희 ·  상상출판 ', '2022.08.03', '16,200'], ['동유럽 셀프트래블(2022-2023)', '박정은 외 ·  상상출판 ', '2022.07.05', '17,550'], ['리얼 싱가포르(2022~2023)', '정지은 ·  한빛라이프 ', '2022.07.05', '16,200'], ['프렌즈 미국 동부(2022~2023)', '이주은 외 ·  중앙북스 ', '2022.07.01', '20,700'], ['떡지순례', '홍금표 ·  비타북스 ', '2022.05.30', '15,300'], ['리얼 제주(2022~2023년)', '김태연 외 ·  한빛라이프 ', '2022.05.02', '15,300'], ['에이든 우리나라 캠핑지도', '타블라라사 편집부 외 ·  타블라라사 ', '2022.01.16', '16,200'], ['자동차로 떠나는 터키 가족여행', '김영 외 ·  북랩 ', '2020.12.28', '14,220'], ['퐁당, 시칠리아', '윤정인 ·  이담북스 ', '2019.11.04', '14,400'], ['시칠리아(2019-2020)', '김문희 외 ·  샬레트래블앤라이프 ', '2019.10.07', '9,000'], ["프렌즈 오키나와('19~'20)(Season 5)", '전명윤 외 ·  중앙북스 ', '2019.06.05', '14,400'], ["프렌즈 타이완('20~'21)(Season 6)", '조현숙 ·  중앙북스 ', '2019.05.27', '15,300'], ['끌림', '이병률 ·  달 ', '2010.07.01', '13,500'], ['스페인 너는 자유다', '손미나 ·  웅진지식하우스 ', '2006.07.28', '11,700'], ['해시태그 폴란드(2023~2024)', '조대현 ·  해시태그 ', '2023.05.24', '17,010'], ['해시태그 조지아(2023~2024)', '조대현 ·  해시태그 ', '2023.05.24', '17,010'], ['해시태그 라오스(2023~2024)', '조대현 ·  해시태그 ', '2023.05.24', '13,770'], ['해시태그 스페인 & 한 달 살기(2023-2024)', '조대현 ·  해시 ...
